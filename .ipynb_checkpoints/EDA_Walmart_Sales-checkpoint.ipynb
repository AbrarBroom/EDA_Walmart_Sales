# %% [markdown]
# ### Importing liberaries & Loading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.float_format','{:.6f}'.format)
df=pd.read_csv('Walmart.csv')
df.head()
# Out:
#    Store        Date   Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010 1643690.900000             0    42.310000    2.572000
# 1      1  12-02-2010 1641957.440000             1    38.510000    2.548000
# 2      1  19-02-2010 1611968.170000             0    39.930000    2.514000
# 3      1  26-02-2010 1409727.590000             0    46.630000    2.561000
# 4      1  05-03-2010 1554806.680000             0    46.500000    2.625000
#
#          CPI  Unemployment
# 0 211.096358      8.106000
# 1 211.242170      8.106000
# 2 211.289143      8.106000
# 3 211.319643      8.106000
# 4 211.350143      8.106000

# %% [markdown]
# ### Quick view in Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.describe()
# Out:
#             Store   Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# count 6435.000000    6435.000000   6435.000000  6435.000000 6435.000000
# mean    23.000000 1046964.877562      0.069930    60.663782    3.358607
# std     12.988182  564366.622054      0.255049    18.444933    0.459020
# min      1.000000  209986.250000      0.000000    -2.060000    2.472000
# 25%     12.000000  553350.105000      0.000000    47.460000    2.933000
# 50%     23.000000  960746.040000      0.000000    62.670000    3.445000
# 75%     34.000000 1420158.660000      0.000000    74.940000    3.735000
# max     45.000000 3818686.450000      1.000000   100.140000    4.468000
#
#               CPI  Unemployment
# count 6435.000000   6435.000000
# mean   171.578394      7.999151
# std     39.356712      1.875885
# min    126.064000      3.879000
# 25%    131.735000      6.891000
# 50%    182.616521      7.874000
# 75%    212.743293      8.622000
# max    227.232807     14.313000

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.nunique()
# Out:
# Store             45
# Date             143
# Weekly_Sales    6435
# Holiday_Flag       2
# Temperature     3528
# Fuel_Price       892
# CPI             2145
# Unemployment     349
# dtype: int64

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.shape
# Out:
# (6435, 8)

# %%
df.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
# Extract the day, month, year from the Date column:
df['Date'] = pd.to_datetime(df['Date'])
df['day'] = df['Date'].dt.weekday
df['month'] = df['Date'].dt.month
df['year']  = df['Date'].dt.year
df.drop('Date',axis=1,inplace=True)
df.head()
# Out:
#    Store   Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price        CPI  \
# 0      1 1643690.900000             0    42.310000    2.572000 211.096358
# 1      1 1641957.440000             1    38.510000    2.548000 211.242170
# 2      1 1611968.170000             0    39.930000    2.514000 211.289143
# 3      1 1409727.590000             0    46.630000    2.561000 211.319643
# 4      1 1554806.680000             0    46.500000    2.625000 211.350143
#
#    Unemployment  day  month  year
# 0      8.106000    6      5  2010
# 1      8.106000    3     12  2010
# 2      8.106000    4      2  2010
# 3      8.106000    4      2  2010
# 4      8.106000    0      5  2010

# %%
# Converting the numerical values to categorical values in the day, month, year, holiday flag columns
# Date column
days = {0:'Sunday',1:'Monday',2:'Tuesday',3:'Wednesday',4:'Thursday',5: 'Friday',6:'Saturday'}
df['day'] = df['day'].map(days)
months={1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'Novemenber',12:'December'}
df['month']= df['month'].map(months)
# Holiday_week column
holiday_week= {1:'Holiday week', 0:'Non-holiday week'}
df['Holiday_Flag']= df['Holiday_Flag'].map(holiday_week)
df.head()
# Out:
#    Store   Weekly_Sales      Holiday_Flag  Temperature  Fuel_Price        CPI  \
# 0      1 1643690.900000  Non-holiday week    42.310000    2.572000 211.096358
# 1      1 1641957.440000      Holiday week    38.510000    2.548000 211.242170
# 2      1 1611968.170000  Non-holiday week    39.930000    2.514000 211.289143
# 3      1 1409727.590000  Non-holiday week    46.630000    2.561000 211.319643
# 4      1 1554806.680000  Non-holiday week    46.500000    2.625000 211.350143
#
#    Unemployment        day     month  year
# 0      8.106000   Saturday       May  2010
# 1      8.106000  Wednesday  December  2010
# 2      8.106000   Thursday  February  2010
# 3      8.106000   Thursday  February  2010
# 4      8.106000     Sunday       May  2010

# %% [markdown]
# ### Outliers

# %%
plt.figure(figsize=(10,8)) 
plt.suptitle('The Distribution of Data', fontsize=18)
dist_cols=['Weekly_Sales', 'Temperature','Fuel_Price', 'CPI', 'Unemployment']
for i in range(0,len(dist_cols)):
    plt.subplot(3,2,i+1)
    sns.boxplot(data=df, y=dist_cols[i])
    plt.title(f'Distribution of {dist_cols[i]}')

# %%
def remove_outlier_IQR(df, cols):
    for col in cols:
        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        IQR=Q3-Q1
        upper_limit= Q3+1.5*IQR
        lower_limit= Q1-1.5*IQR
        df = df[df[col] < upper_limit]
        df = df[df[col] > lower_limit]
    return df

# %%
cols=['Weekly_Sales','Unemployment', 'Temperature']
df=remove_outlier_IQR(df, cols)

# %%
df.shape
# Out:
# (5919, 10)

# %%
# Now check the data after dropping the outliers
plt.figure(figsize=(10,8)) 
plt.suptitle('The Distribution of Data', fontsize=18)
dist_cols=['Weekly_Sales', 'Temperature','Fuel_Price', 'CPI', 'Unemployment']
for i in range(0,len(dist_cols)):
    plt.subplot(3,2,i+1)
    sns.boxplot(data=df, y=dist_cols[i])
    plt.title(f'Distribution of {dist_cols[i]}')

# %% [markdown]
# ### Distribution

# %%
plt.figure(figsize=(10,10)) 
dist_cols=['Weekly_Sales', 'Temperature','Fuel_Price', 'CPI', 'Unemployment']
for i in range(0,len(dist_cols)):
    plt.subplot(3,2,i+1)
    sns.violinplot(data=df, y=dist_cols[i])
    plt.title(f'Distribution of {dist_cols[i]}')

# %%
plt.figure(figsize=(12,15)) 
#plt.suptitle('The Distribution of Data', fontsize=18)
dist_cols=['Weekly_Sales', 'Temperature','Fuel_Price', 'CPI', 'Unemployment']
for i in range(0,len(dist_cols)):
    figure= plt.subplot(3,2,i+1)
    sns.kdeplot(data=df, x=dist_cols[i], hue='Holiday_Flag')
    plt.title(f'Distribution of {dist_cols[i]}')

# %% [markdown]
# ### EDA & Visualization

# %%
df.groupby('year')['Weekly_Sales'].sum().sort_values(ascending=False).to_frame()
# Out:
#           Weekly_Sales
# year
# 2011 2262334375.150000
# 2010 2097829419.810000
# 2012 1791351989.230000

# %%
df.groupby('month')['Weekly_Sales'].sum().sort_values(ascending=False).to_frame()
# Out:
#                Weekly_Sales
# month
# April      597307320.250000
# May        563963943.460000
# October    558074095.280000
# July       552098622.620000
# September  549170809.180000
# June       527832156.500000
# August     523655384.350000
# March      510032348.790000
# December   488244866.480000
# February   483286128.460000
# Novemenber 404107441.830000
# January    393742666.990000

# %%
df.groupby('day')['Weekly_Sales'].sum().sort_values(ascending=False).to_frame()
# Out:
#                Weekly_Sales
# day
# Thursday  4064484119.100000
# Sunday     490964935.310000
# Wednesday  440277537.480000
# Monday     402627762.630000
# Saturday   400694866.370000
# Friday     265553019.100000
# Tuesday     86913544.200000

# %%
plt.figure(figsize=(20,15)) 
cols=['year','month', 'day']
titles=['Yearly','Monthly', 'Daily']
for i in range(0,len(cols)):
    figure= plt.subplot(1,3,i+1)
    plt.pie(df.groupby(cols[i])['Weekly_Sales'].sum().values, labels=df.groupby(cols[i])['Weekly_Sales'].sum().index, autopct='%.2f%%')
    plt.title(f' Total {titles[i]} Sales', color='red', fontsize= 22, fontstyle='italic')

# %%
plt.figure(figsize=(20,15)) 
df1= df[df['year']==2010]
df2= df[df['year']==2011]
df3= df[df['year']==2012]
ddf=[df1, df2, df3]
years=['2010', '2011', '2012']
for i in range(0,len(ddf)):
    figure= plt.subplot(1,3,i+1)
    plt.pie(ddf[i].groupby('month')['Weekly_Sales'].sum().values, labels=ddf[i].groupby('month')['Weekly_Sales'].sum().index, autopct='%.2f%%')
    plt.title(f'{years[i]} Sales per month', color='red', fontsize= 22, fontstyle='italic')

# %%
plt.figure(figsize=(20,15)) 
df1= df[df['year']==2010]
df2= df[df['year']==2011]
df3= df[df['year']==2012]
ddf=[df1, df2, df3]
years=['2010', '2011', '2012']
for i in range(0,len(ddf)):
    figure= plt.subplot(1,3,i+1)
    plt.pie(ddf[i].groupby('day')['Weekly_Sales'].sum().values, labels=ddf[i].groupby('day')['Weekly_Sales'].sum().index, autopct='%.2f%%')
    plt.title(f'{years[i]} Sales per day', color='red', fontsize= 22, fontstyle='italic')

# %%
plt.figure(figsize=(15,15)) 
df1= df[df['year']==2010]
df2= df[df['year']==2011]
df3= df[df['year']==2012]
sns.lineplot(data=df1, x=df1.groupby('month')['Weekly_Sales'].sum().index, y=df1['month'].value_counts().values)
# Out:
# May           252
# December      238
# October       209
# February      168
# March         168
# September     168
# April         168
# July          168
# August        168
# June          126
# Novemenber    121
# January        42
# Name: month, dtype: int64

# %%
df1= df[df['year']==2010]
df1.groupby('month')['Weekly_Sales'].sum()
# Out:
# month
# April        173226304.180000
# August       174453098.270000
# December     261420431.560000
# February     180212497.260000
# January       39825602.620000
# July         173979790.980000
# June         134496227.240000
# March        175232904.620000
# May          264077638.850000
# Novemenber   135502438.680000
# October      215734573.450000
# September    169667912.100000
# Name: Weekly_Sales, dtype: float64

# %%
from calendar import month_name
month_lookup = list(month_name)
sorted(df1.groupby('month')['Weekly_Sales'].sum() , key=month_lookup.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15384/1833035577.py in <module>
#       1 from calendar import month_name
#       2 month_lookup = list(month_name)
# ----> 3 sorted(df1.groupby('month')['Weekly_Sales'].sum() , key=month_lookup.index)
#
# ValueError: 173226304.18 is not in list

# %%
df[df['Store']==20].groupby('day')['Weekly_Sales'].sum().sort_values(ascending=False)
# Out:
# day
# Thursday    180225656.640000
# Sunday       24578956.850000
# Wednesday    21582294.510000
# Saturday     19344425.400000
# Monday       16978321.270000
# Friday       12960926.020000
# Tuesday       4353154.120000
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# ### Machine Learning

# %%
X=df.iloc[:,[3,4,5,6,7]]
Y=df.iloc[:,[2]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, Y, test_size=0.3, random_state=40)

# %% [markdown]
# ### Feature Scalling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
scaler = StandardScaler().fit(X_test)
X_test_scaled = scaler.transform(X_test)
